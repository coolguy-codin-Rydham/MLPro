# %% [markdown]
# # Load Model

# %%
import pickle
import os
import pandas as pd
from datetime import datetime
import numpy as np

# %%
model_path = r"D:\codes\vscode codes\vscode codes\AI\Project\Models\XGBRegressor_r2_0_953_v1.pkl"

model = pickle.load(open(model_path, "rb"))

# %%
model.predict([[ 1.07807977,  0.22192612,  0.77468297,  1.82005277, -1.26200749,
       -0.25194272, -0.12916836, -0.17535463, -0.22754885, -5.47803337,
       -0.64744078, -0.43640293,  0.30459857,  1.74132735, -0.58152447,
       -0.57866842, -0.40630934, -0.40916536, -0.4075004 ,  2.46842407,
       -0.40081071, -0.41367015], [-0.65432992,  1.24504573,  0.23697162, -0.5001855 ,  0.56154562,
       -0.28664608, -0.12916836, -0.17535463, -0.22754885,  0.18254726,
        0.94701966,  0.14260346,  0.30459857, -0.57427456,  1.71961809,
       -0.57866842, -0.40630934, -0.40916536, -0.4075004 , -0.40511677,
        2.49494334, -0.41367015]])
# Out:
# array([  32.777897, 1112.1605  ], dtype=float32)

# %% [markdown]
# # Load SC

# %%
sc_dump_path=r"D:\codes\vscode codes\vscode codes\AI\Project\Models\sc.pkl"

sc = pickle.load(open(sc_dump_path, "rb"))

# %%
sc
# Out:
# StandardScaler()

# %% [markdown]
# # Users Input

# %%
Date="14/04/2024"
Hour = 21
Temperature=34
Humidity = 55
Wind_speed = 67
Visibility = 100
Solar_Radiation = 0.4
Rainfall = 0.7
Snowfall = 0.2
Seasons = "Winter"
Holiday = "No Holiday"
Functioning_Day = "Yes"

# %% [markdown]
# ## Converting Data into Model Consumable Format

# %%
holiday_dic = {
    "No Holiday":0, "Holiday":1
}

functioning_dic = {
    "No":0, "Yes":1
}
def get_string_to_datetime(Date):
    dt = datetime.strptime(Date, "%d/%m/%Y")
    return {"day":dt.day, "month":dt.month, "year":dt.year, "week_day":dt.strftime("%A")}
    


str_to_dat=get_string_to_datetime(Date)
str_to_dat
# Out:
# {'day': 14, 'month': 4, 'year': 2024, 'week_day': 'Sunday'}

# %%
u_input_list = [Hour, Temperature, Humidity, Wind_speed, Visibility,Solar_Radiation, Rainfall, Snowfall, holiday_dic[Holiday], functioning_dic[Functioning_Day],
                str_to_dat["day"], str_to_dat["month"],str_to_dat["year"] ]
features_name = ['Hour', 'Temperature(°C)', 'Humidity(%)',
       'Wind speed (m/s)', 'Visibility (10m)', 'Solar Radiation (MJ/m2)',
       'Rainfall(mm)', 'Snowfall (cm)', 'Holiday', 'Functioning Day', 'Day',
       'Month', 'Year']

# %%
u_input_list
# Out:
# [21, 34, 55, 67, 100, 0.4, 0.7, 0.2, 0, 1, 14, 4, 2024]

# %%
seasons = ["Spring", "Winter", "Summer"]
seasons_data=np.zeroes({1, len(seasons)})

pd.DataFrame()
